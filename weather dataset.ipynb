# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\LAPTOP\\Downloads\\archive\\weather_prediction_dataset.csv")

# %%
df
# Out:
#    BASEL_cloud_cover
# 0                  8
# 1                  8
# 2                  5
# 3                  7
# 4                  5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3654 entries, 0 to 3653
# Columns: 165 entries, DATE to TOURS_temp_max
# dtypes: float64(150), int64(15)
# memory usage: 4.6 MB

# %%
df.describe()
# Out:
#                DATE        MONTH  BASEL_cloud_cover  BASEL_humidity  \
# count  3.654000e+03  3654.000000        3654.000000     3654.000000
# mean   2.004568e+07     6.520799           5.418446        0.745107
# std    2.874287e+04     3.450083           2.325497        0.107788
# min    2.000010e+07     1.000000           0.000000        0.380000
# 25%    2.002070e+07     4.000000           4.000000        0.670000
# 50%    2.004567e+07     7.000000           6.000000        0.760000
# 75%    2.007070e+07    10.000000           7.000000        0.830000
# max    2.010010e+07    12.000000           8.000000        0.980000
#
#        BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# count     3654.000000             3654.000000          3654.000000
# mean         1.017876                1.330380             0.234849
# std          0.007962                0.935348             0.536267
# min          0.985600                0.050000             0.000000
# ...

# %%
df.head(32)
# Out:
#         DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0   20000101      1                  8            0.89          1.0286
# 1   20000102      1                  8            0.87          1.0318
# 2   20000103      1                  5            0.81          1.0314
# 3   20000104      1                  7            0.79          1.0262
# 4   20000105      1                  5            0.90          1.0246
# 5   20000106      1                  3            0.85          1.0244
# 6   20000107      1                  8            0.84          1.0267
# 7   20000108      1                  4            0.79          1.0248
# 8   20000109      1                  8            0.88          1.0243
# 9   20000110      1                  8            0.91          1.0337
# 10  20000111      1                  8            0.88          1.0373
# 11  20000112      1                  8            0.77          1.0319
# ...

# %%
df.tail(10)
# Out:
#           DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 3644  20091223     12                  8            0.93          0.9984
# 3645  20091224     12                  8            0.93          0.9924
# 3646  20091225     12                  6            0.71          1.0025
# 3647  20091226     12                  4            0.81          1.0120
# 3648  20091227     12                  7            0.80          1.0118
# 3649  20091228     12                  7            0.82          1.0084
# 3650  20091229     12                  7            0.92          1.0028
# 3651  20091230     12                  8            0.92          0.9979
# 3652  20091231     12                  7            0.93          0.9958
# 3653  20100101      1                  8            0.93          0.9965
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 3644                    0.36                 0.61             1.1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3654 entries, 0 to 3653
# Columns: 165 entries, DATE to TOURS_temp_max
# dtypes: float64(150), int64(15)
# memory usage: 4.6 MB

# %%
df.columns
# Out:
# Index(['DATE', 'MONTH', 'BASEL_cloud_cover', 'BASEL_humidity',
#        'BASEL_pressure', 'BASEL_global_radiation', 'BASEL_precipitation',
#        'BASEL_sunshine', 'BASEL_temp_mean', 'BASEL_temp_min',
#        ...
#        'STOCKHOLM_temp_min', 'STOCKHOLM_temp_max', 'TOURS_wind_speed',
#        'TOURS_humidity', 'TOURS_pressure', 'TOURS_global_radiation',
#        'TOURS_precipitation', 'TOURS_temp_mean', 'TOURS_temp_min',
#        'TOURS_temp_max'],
#       dtype='object', length=165)

# %%
df.shape
# Out:
# (3654, 165)

# %%
df.isnull()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0     False  False              False           False           False
# 1     False  False              False           False           False
# 2     False  False              False           False           False
# 3     False  False              False           False           False
# 4     False  False              False           False           False
# ...     ...    ...                ...             ...             ...
# 3649  False  False              False           False           False
# 3650  False  False              False           False           False
# 3651  False  False              False           False           False
# 3652  False  False              False           False           False
# 3653  False  False              False           False           False
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# ...

# %%
df.isnull().sum()
# Out:
# DATE                      0
# MONTH                     0
# BASEL_cloud_cover         0
# BASEL_humidity            0
# BASEL_pressure            0
#                          ..
# TOURS_global_radiation    0
# TOURS_precipitation       0
# TOURS_temp_mean           0
# TOURS_temp_min            0
# TOURS_temp_max            0
# Length: 165, dtype: int64

# %%
df.isnull().mean()
# Out:
# DATE                      0.0
# MONTH                     0.0
# BASEL_cloud_cover         0.0
# BASEL_humidity            0.0
# BASEL_pressure            0.0
#                          ...
# TOURS_global_radiation    0.0
# TOURS_precipitation       0.0
# TOURS_temp_mean           0.0
# TOURS_temp_min            0.0
# TOURS_temp_max            0.0
# Length: 165, dtype: float64

# %%
print(df)
# Out:
#           DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0     20000101      1                  8            0.89          1.0286
# 1     20000102      1                  8            0.87          1.0318
# 2     20000103      1                  5            0.81          1.0314
# 3     20000104      1                  7            0.79          1.0262
# 4     20000105      1                  5            0.90          1.0246
# ...        ...    ...                ...             ...             ...
# 3649  20091228     12                  7            0.82          1.0084
# 3650  20091229     12                  7            0.92          1.0028
# 3651  20091230     12                  8            0.92          0.9979
# 3652  20091231     12                  7            0.93          0.9958
# 3653  20100101      1                  8            0.93          0.9965
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# ...

# %%
df.rename(columns={"TOURS_temp_max ":"TOURS_temp_maximum"},inplace=True)

# %%
df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0  20000101      1                  8            0.89          1.0286
# 1  20000102      1                  8            0.87          1.0318
# 2  20000103      1                  5            0.81          1.0314
# 3  20000104      1                  7            0.79          1.0262
# 4  20000105      1                  5            0.90          1.0246
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 0                    0.20                 0.03             0.0
# 1                    0.25                 0.00             0.0
# 2                    0.50                 0.00             3.7
# 3                    0.63                 0.35             6.9
# 4                    0.51                 0.07             3.7
#
#    BASEL_temp_mean  BASEL_temp_min  ...  STOCKHOLM_temp_min  \
# 0              2.9             1.6  ...                -9.3
# ...

# %%
df.shape[0]
# Out:
# 3654

# %%
df.shape[1]
# Out:
# 165

# %%
df.fillna
#if any non value exist in our dataset then fillna give the null value e.g. 0.0 somethig
# Out:
# <bound method NDFrame.fillna of           DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0     20000101      1                  8            0.89          1.0286
# 1     20000102      1                  8            0.87          1.0318
# 2     20000103      1                  5            0.81          1.0314
# 3     20000104      1                  7            0.79          1.0262
# 4     20000105      1                  5            0.90          1.0246
# ...        ...    ...                ...             ...             ...
# 3649  20091228     12                  7            0.82          1.0084
# 3650  20091229     12                  7            0.92          1.0028
# 3651  20091230     12                  8            0.92          0.9979
# 3652  20091231     12                  7            0.93          0.9958
# 3653  20100101      1                  8            0.93          0.9965
#
# ...

# %%
df.dropna()
#Remove rows or columns that contain NaN(null) values
# Out:
#           DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0     20000101      1                  8            0.89          1.0286
# 1     20000102      1                  8            0.87          1.0318
# 2     20000103      1                  5            0.81          1.0314
# 3     20000104      1                  7            0.79          1.0262
# 4     20000105      1                  5            0.90          1.0246
# ...        ...    ...                ...             ...             ...
# 3649  20091228     12                  7            0.82          1.0084
# 3650  20091229     12                  7            0.92          1.0028
# 3651  20091230     12                  8            0.92          0.9979
# 3652  20091231     12                  7            0.93          0.9958
# 3653  20100101      1                  8            0.93          0.9965
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# ...

# %%
df.median()
# Out:
# DATE                      2.004567e+07
# MONTH                     7.000000e+00
# BASEL_cloud_cover         6.000000e+00
# BASEL_humidity            7.600000e-01
# BASEL_pressure            1.017700e+00
#                               ...
# TOURS_global_radiation    1.235000e+00
# TOURS_precipitation       0.000000e+00
# TOURS_temp_mean           1.230000e+01
# TOURS_temp_min            8.300000e+00
# TOURS_temp_max            1.660000e+01
# Length: 165, dtype: float64

# %%
df.mode()
# Out:
#           DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0     20000101    1.0                7.0             0.8          1.0179
# 1     20000102    NaN                NaN             NaN             NaN
# 2     20000103    NaN                NaN             NaN             NaN
# 3     20000104    NaN                NaN             NaN             NaN
# 4     20000105    NaN                NaN             NaN             NaN
# ...        ...    ...                ...             ...             ...
# 3649  20091228    NaN                NaN             NaN             NaN
# 3650  20091229    NaN                NaN             NaN             NaN
# 3651  20091230    NaN                NaN             NaN             NaN
# 3652  20091231    NaN                NaN             NaN             NaN
# 3653  20100101    NaN                NaN             NaN             NaN
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# ...

# %%
df.drop(2, axis=0)
# Out:
#           DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0     20000101      1                  8            0.89          1.0286
# 1     20000102      1                  8            0.87          1.0318
# 3     20000104      1                  7            0.79          1.0262
# 4     20000105      1                  5            0.90          1.0246
# 5     20000106      1                  3            0.85          1.0244
# ...        ...    ...                ...             ...             ...
# 3649  20091228     12                  7            0.82          1.0084
# 3650  20091229     12                  7            0.92          1.0028
# 3651  20091230     12                  8            0.92          0.9979
# 3652  20091231     12                  7            0.93          0.9958
# 3653  20100101      1                  8            0.93          0.9965
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# ...

# %%
df.value_counts()
# Out:
# DATE      MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  BASEL_temp_mean  BASEL_temp_min  BASEL_temp_max  BUDAPEST_cloud_cover  BUDAPEST_humidity  BUDAPEST_pressure  BUDAPEST_global_radiation  BUDAPEST_precipitation  BUDAPEST_sunshine  BUDAPEST_temp_mean  BUDAPEST_temp_max  DE_BILT_cloud_cover  DE_BILT_wind_speed  DE_BILT_wind_gust  DE_BILT_humidity  DE_BILT_pressure  DE_BILT_global_radiation  DE_BILT_precipitation  DE_BILT_sunshine  DE_BILT_temp_mean  DE_BILT_temp_min  DE_BILT_temp_max  DRESDEN_cloud_cover  DRESDEN_wind_speed  DRESDEN_wind_gust  DRESDEN_humidity  DRESDEN_global_radiation  DRESDEN_precipitation  DRESDEN_sunshine  DRESDEN_temp_mean  DRESDEN_temp_min  DRESDEN_temp_max  DUSSELDORF_cloud_cover  DUSSELDORF_wind_speed  DUSSELDORF_wind_gust  DUSSELDORF_humidity  DUSSELDORF_pressure  DUSSELDORF_global_radiation  DUSSELDORF_precipitation  DUSSELDORF_sunshine  DUSSELDORF_temp_mean  DUSSELDORF_temp_min  DUS
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3649    False
# 3650    False
# 3651    False
# 3652    False
# 3653    False
# Length: 3654, dtype: bool

# %%
df.drop("DATE", axis=1)
# Out:
#       MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0         1                  8            0.89          1.0286
# 1         1                  8            0.87          1.0318
# 2         1                  5            0.81          1.0314
# 3         1                  7            0.79          1.0262
# 4         1                  5            0.90          1.0246
# ...     ...                ...             ...             ...
# 3649     12                  7            0.82          1.0084
# 3650     12                  7            0.92          1.0028
# 3651     12                  8            0.92          0.9979
# 3652     12                  7            0.93          0.9958
# 3653      1                  8            0.93          0.9965
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 0                       0.20                 0.03             0.0
# 1                       0.25                 0.00             0.0
# ...

# %%
df.std()
#standard deviation
#Standard deviation tells us how spread out the data is from the mean.
# Out:
# DATE                      28742.871733
# MONTH                         3.450083
# BASEL_cloud_cover             2.325497
# BASEL_humidity                0.107788
# BASEL_pressure                0.007962
#                               ...
# TOURS_global_radiation        0.926472
# TOURS_precipitation           0.422151
# TOURS_temp_mean               6.467155
# TOURS_temp_min                5.692256
# TOURS_temp_max                7.714924
# Length: 165, dtype: float64

# %%
import pandas as pd

df = pd.DataFrame({
    "BASEL_cloud_cover": [8, 8, 5, 7, 5]
})

print("Standard Deviation:", df['BASEL_cloud_cover'].std())
# Out:
# Standard Deviation: 1.51657508881031

# %%
df.sort_values("BASEL_humidity", ascending=False)
# Out:
#           DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 525   20010609      6                  8            0.98          1.0133
# 1800  20041205     12                  8            0.98          1.0302
# 561   20010715      7                  8            0.97          1.0160
# 699   20011130     11                  8            0.97          1.0183
# 1794  20041129     11                  8            0.97          1.0135
# ...        ...    ...                ...             ...             ...
# 1317  20030810      8                  0            0.42          1.0154
# 1193  20030408      4                  1            0.40          1.0200
# 1319  20030812      8                  1            0.40          1.0201
# 1320  20030813      8                  3            0.39          1.0177
# 826   20020406      4                  3            0.38          1.0119
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# ...

# %%
df['BASEL_pressure'].std()
# Out:
# 0.007962326669476423
